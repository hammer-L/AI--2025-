# %%
import torch
from transformers import AutoModel, AutoProcessor
from transformers.image_utils import load_image

# load the model and processor
ckpt = "google/siglip2-base-patch16-224"
model = AutoModel.from_pretrained(ckpt).eval()
processor = AutoProcessor.from_pretrained(ckpt, trust_remote_code=True)

# load the image
image = load_image("https://huggingface.co/datasets/merve/coco/resolve/main/val2017/000000000285.jpg")
inputs = processor(images=[image], return_tensors="pt").to(model.device)

# run infernece
with torch.no_grad():
    image_embeddings = model.get_image_features(**inputs)    

print(image_embeddings.shape)
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GemmaTokenizer'.
# The class this function is called from is 'SiglipTokenizer'.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 8
#       6 ckpt = "google/siglip2-base-patch16-224"
#       7 model = AutoModel.from_pretrained(ckpt).eval()
# ----> 8 processor = AutoProcessor.from_pretrained(ckpt, trust_remote_code=True)
#      10 # load the image
#      11 image = load_image("https://huggingface.co/datasets/merve/coco/resolve/main/val2017/000000000285.jpg")
#
# File E:\anacoda\envs\pytorch\lib\site-packages\transformers\models\auto\processing_auto.py:328, in AutoProcessor.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     324     return processor_class.from_pretrained(
#     325         pretrained_model_name_or_path, trust_remote_code=trust_remote_code, **kwargs
#     326     )
#     327 elif processor_class is not None:
# --> 328     return processor_class.from_pretrained(
#     329         pretrained_model_name_or_path, trust_remote_code=trust_remote_code, **kwargs
#     330     )
#     331 # Last try: we use the PROCESSOR_MAPPING.
#     332 elif type(config) in PROCESSOR_MAPPING:
#
# File E:\anacoda\envs\pytorch\lib\site-packages\transformers\processing_utils.py:944, in ProcessorMixin.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, **kwargs)
#     941 if token is not None:
#     942     kwargs["token"] = token
# --> 944 args = cls._get_arguments_from_pretrained(pretrained_model_name_or_path, **kwargs)
#     945 processor_dict, kwargs = cls.get_processor_dict(pretrained_model_name_or_path, **kwargs)
#     947 return cls.from_args_and_dict(args, processor_dict, **kwargs)
#
# File E:\anacoda\envs\pytorch\lib\site-packages\transformers\processing_utils.py:990, in ProcessorMixin._get_arguments_from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     987     else:
#     988         attribute_class = getattr(transformers_module, class_name)
# --> 990     args.append(attribute_class.from_pretrained(pretrained_model_name_or_path, **kwargs))
#     991 return args
#
# File E:\anacoda\envs\pytorch\lib\site-packages\transformers\tokenization_utils_base.py:2213, in PreTrainedTokenizerBase.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    2210     else:
#    2211         logger.info(f"loading file {file_path} from cache at {resolved_vocab_files[file_id]}")
# -> 2213 return cls._from_pretrained(
#    2214     resolved_vocab_files,
#    2215     pretrained_model_name_or_path,
#    2216     init_configuration,
#    2217     *init_inputs,
#    2218     token=token,
#    2219     cache_dir=cache_dir,
#    2220     local_files_only=local_files_only,
#    2221     _commit_hash=commit_hash,
#    2222     _is_local=is_local,
#    2223     trust_remote_code=trust_remote_code,
#    2224     **kwargs,
#    2225 )
#
# File E:\anacoda\envs\pytorch\lib\site-packages\transformers\tokenization_utils_base.py:2447, in PreTrainedTokenizerBase._from_pretrained(cls, resolved_vocab_files, pretrained_model_name_or_path, init_configuration, token, cache_dir, local_files_only, _commit_hash, _is_local, trust_remote_code, *init_inputs, **kwargs)
#    2445 # Instantiate the tokenizer.
#    2446 try:
# -> 2447     tokenizer = cls(*init_inputs, **init_kwargs)
#    2448 except import_protobuf_decode_error():
#    2449     logger.info(
#    2450         "Unable to load tokenizer model from SPM, loading from TikToken will be attempted instead."
#    2451         "(Google protobuf error: Tried to load SPM model with non-SPM vocab file).",
#    2452     )
#
# File E:\anacoda\envs\pytorch\lib\site-packages\transformers\models\siglip\tokenization_siglip.py:123, in SiglipTokenizer.__init__(self, vocab_file, eos_token, unk_token, pad_token, additional_special_tokens, sp_model_kwargs, model_max_length, do_lower_case, **kwargs)
#     120 self.do_lower_case = do_lower_case
#     121 self.vocab_file = vocab_file
# --> 123 self.sp_model = self.get_spm_processor()
#     124 self.vocab_file = vocab_file
#     126 super().__init__(
#     127     eos_token=eos_token,
#     128     unk_token=unk_token,
#    (...)
#     134     **kwargs,
#     135 )
#
# File E:\anacoda\envs\pytorch\lib\site-packages\transformers\models\siglip\tokenization_siglip.py:139, in SiglipTokenizer.get_spm_processor(self)
#     137 def get_spm_processor(self):
#     138     tokenizer = spm.SentencePieceProcessor(**self.sp_model_kwargs)
# --> 139     with open(self.vocab_file, "rb") as f:
#     140         sp_model = f.read()
#     141         model_pb2 = import_protobuf()
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from transformers import pipeline
from PIL import Image
import requests
from transformers import AutoProcessor, AutoModel
import torch
 
dtype = torch.float32
device = "cuda" if torch.cuda.is_available() else "cpu"
 
checkpoint = "google/siglip2-base-patch16-224"
 
# load pipeline
image_classifier = pipeline(task="zero-shot-image-classification",model="google/siglip2-base-patch16-224",)
path ="2cat.jpg"
image = Image.open(path)
candidate_labels = ["2 cats", "a plane", "a remote"]
outputs = image_classifier(image, candidate_labels=candidate_labels)
outputs = [{"score": round(output["score"], 4), "label": output["label"] } for output in outputs]
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Asking to pad to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no padding.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File E:\anacoda\envs\pytorch\lib\site-packages\transformers\tokenization_utils_base.py:776, in BatchEncoding.convert_to_tensors(self, tensor_type, prepend_batch_axis)
#     775 if not is_tensor(value):
# --> 776     tensor = as_tensor(value)
#     778     # Removing this for now in favor of controlling the shape with `prepend_batch_axis`
#     779     # # at-least2d
#     780     # if tensor.ndim > 2:
#     781     #     tensor = tensor.squeeze(0)
#     782     # elif tensor.ndim < 2:
#     783     #     tensor = tensor[None, :]
#
# File E:\anacoda\envs\pytorch\lib\site-packages\transformers\tokenization_utils_base.py:738, in BatchEncoding.convert_to_tensors.<locals>.as_tensor(value, dtype)
#     737     return torch.from_numpy(np.array(value))
# --> 738 return torch.tensor(value)
#
# ValueError: expected sequence of length 10 at dim 1 (got 9)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 17
#      15 image = Image.open(path)
#      16 candidate_labels = ["2 cats", "a plane", "a remote"]
# ---> 17 outputs = image_classifier(image, candidate_labels=candidate_labels)
#      18 outputs = [{"score": round(output["score"], 4), "label": output["label"] } for output in outputs]
#
# File E:\anacoda\envs\pytorch\lib\site-packages\transformers\pipelines\zero_shot_image_classification.py:109, in ZeroShotImageClassificationPipeline.__call__(self, image, **kwargs)
#     107 if image is None:
#     108     raise ValueError("Cannot call the zero-shot-image-classification pipeline without an images argument!")
# --> 109 return super().__call__(image, **kwargs)
#
# File E:\anacoda\envs\pytorch\lib\site-packages\transformers\pipelines\base.py:1302, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1294     return next(
#    1295         iter(
#    1296             self.get_iterator(
#    (...)
#    1299         )
#    1300     )
#    1301 else:
# -> 1302     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File E:\anacoda\envs\pytorch\lib\site-packages\transformers\pipelines\base.py:1308, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1307 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
# -> 1308     model_inputs = self.preprocess(inputs, **preprocess_params)
#    1309     model_outputs = self.forward(model_inputs, **forward_params)
#    1310     outputs = self.postprocess(model_outputs, **postprocess_params)
#
# File E:\anacoda\envs\pytorch\lib\site-packages\transformers\pipelines\zero_shot_image_classification.py:148, in ZeroShotImageClassificationPipeline.preprocess(self, image, candidate_labels, hypothesis_template, timeout, tokenizer_kwargs)
#     146 sequences = [hypothesis_template.format(x) for x in candidate_labels]
#     147 padding = "max_length" if self.model.config.model_type == "siglip" else True
# --> 148 text_inputs = self.tokenizer(sequences, return_tensors=self.framework, padding=padding, **tokenizer_kwargs)
#     149 inputs["text_inputs"] = [text_inputs]
#     150 return inputs
#
# File E:\anacoda\envs\pytorch\lib\site-packages\transformers\tokenization_utils_base.py:3021, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    3019     if not self._in_target_context_manager:
#    3020         self._switch_to_input_mode()
# -> 3021     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    3022 if text_target is not None:
#    3023     self._switch_to_target_mode()
#
# File E:\anacoda\envs\pytorch\lib\site-packages\transformers\tokenization_utils_base.py:3109, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    3104         raise ValueError(
#    3105             f"batch length of `text`: {len(text)} does not match batch length of `text_pair`:"
#    3106             f" {len(text_pair)}."
#    3107         )
#    3108     batch_text_or_text_pairs = list(zip(text, text_pair)) if text_pair is not None else text
# -> 3109     return self.batch_encode_plus(
#    3110         batch_text_or_text_pairs=batch_text_or_text_pairs,
#    3111         add_special_tokens=add_special_tokens,
#    3112         padding=padding,
#    3113         truncation=truncation,
#    3114         max_length=max_length,
#    3115         stride=stride,
#    3116         is_split_into_words=is_split_into_words,
#    3117         pad_to_multiple_of=pad_to_multiple_of,
#    3118         padding_side=padding_side,
#    3119         return_tensors=return_tensors,
#    3120         return_token_type_ids=return_token_type_ids,
#    3121         return_attention_mask=return_attention_mask,
#    3122         return_overflowing_tokens=return_overflowing_tokens,
#    3123         return_special_tokens_mask=return_special_tokens_mask,
#    3124         return_offsets_mapping=return_offsets_mapping,
#    3125         return_length=return_length,
#    3126         verbose=verbose,
#    3127         split_special_tokens=split_special_tokens,
#    3128         **kwargs,
#    3129     )
#    3130 else:
#    3131     return self.encode_plus(
#    3132         text=text,
#    3133         text_pair=text_pair,
#    (...)
#    3151         **kwargs,
#    3152     )
#
# File E:\anacoda\envs\pytorch\lib\site-packages\transformers\tokenization_utils_base.py:3311, in PreTrainedTokenizerBase.batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    3301 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
#    3302 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    3303     padding=padding,
#    3304     truncation=truncation,
#    (...)
#    3308     **kwargs,
#    3309 )
# -> 3311 return self._batch_encode_plus(
#    3312     batch_text_or_text_pairs=batch_text_or_text_pairs,
#    3313     add_special_tokens=add_special_tokens,
#    3314     padding_strategy=padding_strategy,
#    3315     truncation_strategy=truncation_strategy,
#    3316     max_length=max_length,
#    3317     stride=stride,
#    3318     is_split_into_words=is_split_into_words,
#    3319     pad_to_multiple_of=pad_to_multiple_of,
#    3320     padding_side=padding_side,
#    3321     return_tensors=return_tensors,
#    3322     return_token_type_ids=return_token_type_ids,
#    3323     return_attention_mask=return_attention_mask,
#    3324     return_overflowing_tokens=return_overflowing_tokens,
#    3325     return_special_tokens_mask=return_special_tokens_mask,
#    3326     return_offsets_mapping=return_offsets_mapping,
#    3327     return_length=return_length,
#    3328     verbose=verbose,
#    3329     split_special_tokens=split_special_tokens,
#    3330     **kwargs,
#    3331 )
#
# File E:\anacoda\envs\pytorch\lib\site-packages\transformers\tokenization_utils_fast.py:577, in PreTrainedTokenizerFast._batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens)
#     575 for input_ids in sanitized_tokens["input_ids"]:
#     576     self._eventual_warn_about_too_long_sequence(input_ids, max_length, verbose)
# --> 577 return BatchEncoding(sanitized_tokens, sanitized_encodings, tensor_type=return_tensors)
#
# File E:\anacoda\envs\pytorch\lib\site-packages\transformers\tokenization_utils_base.py:240, in BatchEncoding.__init__(self, data, encoding, tensor_type, prepend_batch_axis, n_sequences)
#     236     n_sequences = encoding[0].n_sequences
#     238 self._n_sequences = n_sequences
# --> 240 self.convert_to_tensors(tensor_type=tensor_type, prepend_batch_axis=prepend_batch_axis)
#
# File E:\anacoda\envs\pytorch\lib\site-packages\transformers\tokenization_utils_base.py:792, in BatchEncoding.convert_to_tensors(self, tensor_type, prepend_batch_axis)
#     787         if key == "overflowing_tokens":
#     788             raise ValueError(
#     789                 "Unable to create tensor returning overflowing tokens of different lengths. "
#     790                 "Please see if a fast version of this tokenizer is available to have this feature available."
#     791             ) from e
# --> 792         raise ValueError(
#     793             "Unable to create tensor, you should probably activate truncation and/or padding with"
#     794             " 'padding=True' 'truncation=True' to have batched tensors with the same length. Perhaps your"
#     795             f" features (`{key}` in this case) have excessive nesting (inputs type `list` where type `int` is"
#     796             " expected)."
#     797         ) from e
#     799 return self
#
# ValueError: Unable to create tensor, you should probably activate truncation and/or padding with 'padding=True' 'truncation=True' to have batched tensors with the same length. Perhaps your features (`input_ids` in this case) have excessive nesting (inputs type `list` where type `int` is expected).
